# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv(r'c:/users/91991/downloads/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df2=pd.read_csv(r'c:/users/91991/downloads/happiness_score_dataset.csv',index_col='Country')
df2
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
df2.head()
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
# Denmark      Western Europe               3            7.527         0.03328
# Norway       Western Europe               4            7.522         0.03880
# Canada        North America               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
# ...

# %%
df2.tail()
# Out:
#                                   Region  Happiness Rank  Happiness Score  \
# Country
# Rwanda                Sub-Saharan Africa             154            3.465
# Benin                 Sub-Saharan Africa             155            3.340
# Syria    Middle East and Northern Africa             156            3.006
# Burundi               Sub-Saharan Africa             157            2.905
# Togo                  Sub-Saharan Africa             158            2.839
#
#          Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Rwanda          0.03464                   0.22208  0.77370
# Benin           0.03656                   0.28665  0.35386
# Syria           0.05015                   0.66320  0.47489
# Burundi         0.08658                   0.01530  0.41587
# Togo            0.06727                   0.20868  0.13995
#
#          Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# Country
# ...

# %%
df2.shape
# Out:
# (158, 11)

# %%
df2.dtypes
# Out:
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df2.isnull().sum()
# Out:
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# THERE IS NO NULL VALUES IN THE DATASET

# %%
df2
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
df2 = df2.rename(columns={'Happiness Score':'Happiness_Score'})
df2 = df2.rename(columns={'Happiness Rank':'Happiness_Rank'})
df2
# Out:
#                                       Region  Happiness_Rank  Happiness_Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
df2 = df2.rename(columns={'Economy (GDP per Capita)':'Economy','Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Trust','Dystopia Residual':'Dystopia'})

# %%
df2
# Out:
#                                       Region  Happiness_Rank  Happiness_Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %% [markdown]
# DATA VISUALISATION

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Happiness_Rank'])
plt.title('Happiness_Rank')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Happiness_Score'])
plt.title('Happiness_Score')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Economy'])
plt.title('Economy')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Family'])
plt.title('Family')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Health'])
plt.title('Health')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Freedom'])
plt.title('Freedom')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Trust'])
plt.title('Trust')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df2['Generosity'])
plt.title('Generosity')
plt.show()

# %% [markdown]
# FROM ALL THE DISTPLOT WE CAN SEE THAT ALL THE DATA IS NORMALLY DISTRIBUTED

# %%
df2.corr()
# Out:
#                  Happiness_Rank  Happiness_Score  Standard Error   Economy  \
# Happiness_Rank         1.000000        -0.992105        0.158516 -0.785267
# Happiness_Score       -0.992105         1.000000       -0.177254  0.780966
# Standard Error         0.158516        -0.177254        1.000000 -0.217651
# Economy               -0.785267         0.780966       -0.217651  1.000000
# Family                -0.733644         0.740605       -0.120728  0.645299
# Health                -0.735613         0.724200       -0.310287  0.816478
# Freedom               -0.556886         0.568211       -0.129773  0.370300
# Trust                 -0.372315         0.395199       -0.178325  0.307885
# Generosity            -0.160142         0.180319       -0.088439 -0.010465
# Dystopia              -0.521999         0.530474        0.083981  0.040059
#
#                    Family    Health   Freedom     Trust  Generosity  Dystopia
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# FAMILY,HEALTH,FREEDOM AND TRUST ARE HIGHLY CORRELATED WITH HAPPINESS SCORE

# %%
#NOW LETS CHECK FOR OUTLIERS
df2['Standard Error'].plot.box()
plt.show()

# %%
df2['Economy'].plot.box()
plt.show()

# %%
df2['Family'].plot.box()
plt.show()

# %%
df2['Health'].plot.box()
plt.show()

# %%
df2['Trust'].plot.box()
plt.show()

# %%
df2['Generosity'].plot.box()
plt.show()

# %%
df2['Dystopia'].plot.box()
plt.show()

# %%
#lets remove outliers by zscore but before that we need to drop region column
df2.drop('Region',axis=1,inplace=True)
df2
# Out:
#              Happiness_Rank  Happiness_Score  Standard Error  Economy  \
# Country
# Switzerland               1            7.587         0.03411  1.39651
# Iceland                   2            7.561         0.04884  1.30232
# Denmark                   3            7.527         0.03328  1.32548
# Norway                    4            7.522         0.03880  1.45900
# Canada                    5            7.427         0.03553  1.32629
# ...                     ...              ...             ...      ...
# Rwanda                  154            3.465         0.03464  0.22208
# Benin                   155            3.340         0.03656  0.28665
# Syria                   156            3.006         0.05015  0.66320
# Burundi                 157            2.905         0.08658  0.01530
# Togo                    158            2.839         0.06727  0.20868
#
#               Family   Health  Freedom    Trust  Generosity  Dystopia
# Country
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df2))

# %%
z
# Out:
#              Happiness_Rank  Happiness_Score  Standard Error   Economy  \
# Country
# Switzerland        1.721000         1.937360        0.805926  1.369621
# Iceland            1.699075         1.914581        0.055889  1.135226
# Denmark            1.677149         1.884792        0.854487  1.192861
# Norway             1.655224         1.880411        0.531526  1.525130
# Canada             1.633299         1.797179        0.722845  1.194876
# ...                     ...              ...             ...       ...
# Rwanda             1.633576         1.674055        0.774917  1.552987
# Benin              1.655501         1.783571        0.662582  1.392303
# Syria              1.677427         2.076199        0.132534  0.455245
# Burundi            1.699352         2.164688        2.263962  2.067566
# Togo               1.721277         2.222513        1.134182  1.586334
#
#                Family    Health   Freedom     Trust  Generosity  Dystopia
# Country
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df2=df2[(z<3).all(axis=1)]
df2
# Out:
#               Happiness_Rank  Happiness_Score  Standard Error  Economy  \
# Country
# Switzerland                1            7.587         0.03411  1.39651
# Iceland                    2            7.561         0.04884  1.30232
# Denmark                    3            7.527         0.03328  1.32548
# Norway                     4            7.522         0.03880  1.45900
# Canada                     5            7.427         0.03553  1.32629
# ...                      ...              ...             ...      ...
# Ivory Coast              151            3.655         0.05141  0.46534
# Burkina Faso             152            3.587         0.04324  0.25812
# Afghanistan              153            3.575         0.03084  0.31982
# Benin                    155            3.340         0.03656  0.28665
# Burundi                  157            2.905         0.08658  0.01530
#
#                Family   Health  Freedom    Trust  Generosity  Dystopia
# Country
# ...

# %%
df2.shape
# Out:
# (149, 10)

# %%
df.shape
# Out:
# (158, 12)

# %%
#NOW LETS SPLIT THE DATA INTO X AND Y

x=df2.drop('Happiness_Score',axis=1)
x
# Out:
#               Happiness_Rank  Standard Error  Economy   Family   Health  \
# Country
# Switzerland                1         0.03411  1.39651  1.34951  0.94143
# Iceland                    2         0.04884  1.30232  1.40223  0.94784
# Denmark                    3         0.03328  1.32548  1.36058  0.87464
# Norway                     4         0.03880  1.45900  1.33095  0.88521
# Canada                     5         0.03553  1.32629  1.32261  0.90563
# ...                      ...             ...      ...      ...      ...
# Ivory Coast              151         0.05141  0.46534  0.77115  0.15185
# Burkina Faso             152         0.04324  0.25812  0.85188  0.27125
# Afghanistan              153         0.03084  0.31982  0.30285  0.30335
# Benin                    155         0.03656  0.28665  0.35386  0.31910
# Burundi                  157         0.08658  0.01530  0.41587  0.22396
#
#               Freedom    Trust  Generosity  Dystopia
# Country
# ...

# %%
y=df2['Happiness_Score']
y
# Out:
# Country
# Switzerland     7.587
# Iceland         7.561
# Denmark         7.527
# Norway          7.522
# Canada          7.427
#                 ...
# Ivory Coast     3.655
# Burkina Faso    3.587
# Afghanistan     3.575
# Benin           3.340
# Burundi         2.905
# Name: Happiness_Score, Length: 149, dtype: float64

# %% [markdown]
# CLASSIFICATIONS MODEL

# %% [markdown]
# IMPORTING LIBRARIES

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=3)

# %%
x_train.shape
# Out:
# (119, 9)

# %%
x_test.shape
# Out:
# (30, 9)

# %%
y_train.shape
# Out:
# (119,)

# %%
y_test.shape
# Out:
# (30,)

# %%
le=LinearRegression()

# %%
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
le.score(x_train,y_train)
# Out:
# 0.9999999408153387

# %%
lepred=le.predict(x_test)

# %%
print('predicted value and actual value',y_test,lepred)
# Out:
# predicted value and actual value Country
# Lebanon              4.839
# Guatemala            6.123
# Norway               7.522
# Lithuania            5.833
# Italy                5.948
# Brazil               6.983
# Netherlands          7.378
# Zimbabwe             4.610
# Kyrgyzstan           5.286
# Somaliland region    5.057
# Tanzania             3.781
# Germany              6.750
# Suriname             6.269
# Morocco              5.013
# Malawi               4.292
# Macedonia            5.007
# India                4.565
# Azerbaijan           5.212
# Uzbekistan           6.003
# Bulgaria             4.218
# Mali                 3.995
# Colombia             6.477
# Finland              7.406
# Tajikistan           4.786
# Hong Kong            5.474
# Malaysia             5.770
# Kosovo               5.589
# Pakistan             5.194
# United States        7.119
# Panama               6.786
# ...

# %%
print('mean squared error',mean_squared_error(y_test,lepred))
print('mean absolute error',mean_absolute_error(y_test,lepred))
print('r2_score',r2_score(y_test,lepred))
# Out:
# mean squared error 9.062350069041349e-08
# mean absolute error 0.0002640993872903656
# r2_score 0.9999999178333291

# %% [markdown]
# Mean Squared Error (MSE) value is 9.062350069038218e-08 which indicates that, on average, the squared difference between the actual and predicted values is very small. Lower values of MSE indicate better performance.
#
# Mean absolute error 0.00026409938729026193 is again very small, indicating that, on average, the absolute difference between the actual and predicted values is very small.
#
# R2_score 0.9999999178333291 which is very close to 1, indicating that our model explains almost all of the variability of the dependent variable around its mean. In simpler terms, Our model fits the data extremely well
